# %% [markdown]
# #### Create a DataFrame

# %%
from pyspark.sql.functions import *

emp_data = [(1,"Sourav", 5600),(2,"Rajesh",3500)]

emp_df = spark.createDataFrame(emp_data , ["id","name","salary"])

emp_df.show()

# %% [markdown]
# ### Read a CSV File

# %%
from pyspark.sql.functions import *

read_csv = spark.read.csv("/Volumes/workspace/default/bigmart/BigMart Sales.csv", header=True, inferSchema=True)

read_csv.show()
